# %%
import spacy
from spacy import displacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp(u"The quick brown fox jumped over the lazy dog's back.")

# %%
print(doc.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-1bfd6ca32aa7> in <module>
# ----> 1 print(doc.text)
#
# NameError: name 'doc' is not defined

# %%
for token in doc:
    print(f"{token.text:{20}} {token.pos_:{10}} {token.tag_:{10}} {spacy.explain(token.tag_)}")

# %%
doc = nlp(u"I always read books on NLP.")

# %%
word = doc[2]

# %%
token = word 
print(f"{token.text:{20}} {token.pos_:{10}} {token.tag_:{10}} {spacy.explain(token.tag_)}")
# Out:
# read                 VERB       VBP        verb, non-3rd person singular present

# %%
doc = nlp(u"The quick brown fox jumped over the lazy dog's back")

# %%
POS_counts = doc.count_by(spacy.attrs.POS)

# %%
POS_counts
# Out:
# {90: 2, 84: 3, 92: 3, 100: 1, 85: 1, 94: 1}

# %%
doc.vocab[100].text
# Out:
# 'VERB'

# %%
for k, v in sorted(POS_counts.items()):
    print(f"{k}. {doc.vocab[k].text:{10}} {v}")
# Out:
# 84. ADJ        3
# 85. ADP        1
# 90. DET        2
# 92. NOUN       3
# 94. PART       1
# 100. VERB       1

# %%
TAG_counts = doc.count_by(spacy.attrs.TAG)

for k, v in sorted(TAG_counts.items()):
    print(f"{k}. {doc.vocab[k].text:{5}} {v}")
# Out:
# 74. POS   1
# 1292078113972184607. IN    1
# 10554686591937588953. JJ    3
# 15267657372422890137. DT    2
# 15308085513773655218. NN    3
# 17109001835818727656. VBD   1

# %%
#Syntactic dependency 
DEP_counts = doc.count_by(spacy.attrs.DEP)

for k, v in sorted(DEP_counts.items()):
    print(f"{k}. {doc.vocab[k].text:{5}} {v}")
# Out:
# 402. amod  3
# 415. det   2
# 429. nsubj 1
# 439. pobj  1
# 440. poss  1
# 443. prep  1
# 8110129090154140942. case  1
# 8206900633647566924. ROOT  1

# %%
displacy.render(doc, style='dep', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="05976785df9146e0acd33d7362b12f64-0" class="displacy" width="1975" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">quick</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
# ...

# %%
options  = {'distance':110, 'compact':'True', 'color':'yellow', 'bg':'#09a3d5', 'font':'Times'}

# %%
displacy.render(doc, style='dep', jupyter=True, options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="6665f68d36184e89bc5b87dcc878048b-0" class="displacy" width="1260" height="357.0" direction="ltr" style="max-width: none; height: 357.0px; color: yellow; background: #09a3d5; font-family: Times; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">quick</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
# ...

# %%
doc2 = nlp(u"This is the first sentence. This is the second sentence. I really love playing football")

# %%
spans = list(doc2.sents)

# %%
displacy.serve(spans, style='dep', options= options)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\spacy\displacy\__init__.py:97: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# ...
